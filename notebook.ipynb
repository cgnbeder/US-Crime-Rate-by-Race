# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Arrests, by Race and Ethnicity, 2019**
#
# The FBI collects these data through the Uniform Crime Reporting (UCR) Program.
#
# **Important note about rape data**
#
# In 2013, the FBI’s UCR Program initiated the collection of rape data under a revised definition within the Summary Reporting System. The term “forcible” was removed from the offense name, and the definition was changed to “penetration, no matter how slight, of the vagina or anus with any body part or object, or oral penetration by a sex organ of another person, without the consent of the victim.”
#
# In 2016, the FBI Director approved the recommendation to discontinue the reporting of rape data using the UCR legacy definition beginning in 2017.
#
# **General comments**
#
# This table provides the number of persons arrested nationwide in 2019 broken down by race and ethnicity of the arrestee. In addition, the table shows the percent distribution of arrests by race and ethnicity for each offense. The table also furnishes a breakdown of these data by juveniles (persons under age 18) and adults.
# The totals provided in this table reflect only those persons arrested by law enforcement agencies that provided race information to the UCR Program; therefore, the totals may not match those shown in other arrest tables for the nation.
# These data represent the number of persons arrested; however, some persons may be arrested more than once during a year. Therefore, the statistics in this table could, in some cases, represent multiple arrests of the same person.
#
# **Methodology**
#
# - The data used in creating this table were from all law enforcement agencies submitting 12 months of arrest data, including race information, for 2019.
# - The rape figures in this table are aggregate totals of data submitted using both the legacy and revised UCR definitions of rape.
#
# **Population estimation**
#
# For the 2019 population estimates used in this table, the FBI computed individual rates of growth from one year to the next for every city/town and county using 2010 decennial population counts and 2011 through 2018 population estimates from the U.S. Census Bureau. Each agency’s rates of growth were averaged; that average was then applied and added to its 2018 Census population estimate to derive the agency’s 2019 population estimate.

# %%
import pandas as pd

df = pd.read_excel("edited_fbi_table43.xlsx")
df.columns = df.columns.str.strip()
df.columns = df.columns.str.capitalize()
print(df.isnull().any())
print("--------------------")
print(df.info)
# Out:
# Offense charged                                    False
# Total                                              False
# White                                              False
# Black or\nafrican\namerican                        False
# American\nindian or\nalaska\nnative                False
# Asian                                              False
# Native\nhawaiian\nor other\npacific\nislander      False
# Total.1                                            False
# White.1                                            False
# Black or\nafrican\namerican.1                      False
# American\nindian or\nalaska\nnative.1              False
# Asian.1                                            False
# Native\nhawaiian\nor other\npacific\nislander.1    False
# Total.2                                            False
# Hispanic\nor\nlatino                               False
# Not\nhispanic\nor latino                           False
# Total.3                                            False
# Hispanic\nor\nlatino.1                             False
# Not\nhispanic\nor latino.1                         False
# dtype: bool
# --------------------
# <bound method DataFrame.info of                                    Offense charged  ...  Not\nhispanic\nor latino.1
# 0                                            TOTAL  ...                        80.9
# 1             Murder and nonnegligent manslaughter  ...                        79.3
# 2                                             Rape  ...                        72.1
# 3                                          Robbery  ...                        76.3
# 4                               Aggravated assault  ...                        74.3
# 5                                         Burglary  ...                        79.2
# 6                                    Larceny-theft  ...                        85.2
# 7                              Motor vehicle theft  ...                        74.8
# 8                                            Arson  ...                        81.3
# 9                                    Violent crime  ...                        74.7
# 10                                  Property crime  ...                        83.4
# 11                                  Other assaults  ...                        81.1
# 12                      Forgery and counterfeiting  ...                        83.1
# 13                                           Fraud  ...                        85.4
# 14                                    Embezzlement  ...                        86.7
# 15  Stolen property; buying, receiving, possessing  ...                        81.2
# 16                                       Vandalism  ...                        80.6
# 17             Weapons; carrying, possessing, etc.  ...                        76.2
# 18            Prostitution and commercialized vice  ...                        80.7
# 19     Sex offenses (except rape and prostitution)  ...                        72.1
# 20                           Drug abuse violations  ...                        79.4
# 21                                        Gambling  ...                        74.2
# 22        Offenses against the family and children  ...                        87.0
# 23                     Driving under the influence  ...                        73.6
# 24                                     Liquor laws  ...                        83.6
# 25                                     Drunkenness  ...                        77.4
# 26                              Disorderly conduct  ...                        86.1
# 27                                        Vagrancy  ...                        85.7
# 28             All other offenses (except traffic)  ...                        83.6
# 29                                       Suspicion  ...                        91.0
# 30             Curfew and loitering law violations  ...                        74.3
#
# [31 rows x 19 columns]>
